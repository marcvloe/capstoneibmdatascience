# %% [markdown]
# 1.Objective of or Mission:
#
#
# Our objective is to find an prediction model that based on the earlier recorded traffic accidents that would enable us to predict the severity of an accident and the possible delay resulting for the incident.
#
# Groups or publics which could be interested or benifit of such models:
#
# We various groups who could be interested in such model.
#
#
#
# 1.2.Authorities:
#
#
# Having such model to their disposal they could check which circurmstances are cause of an increased risk of accident.
#
# Once these elements determined where ever possible dispostions could take to take control or to infleunce these circumstance in such way that they become less prone to cause accidents.
#
# This can be done by permanent restrictions or with panels which can be activated or on which the restriction messages can be diffulgated.
# To monitor and if needed sanctin the non respect of these restrictions.
#
# Authorities can also adapt the road in such way taking into consideration the factors which influences road accidents.
#
#
# 1.3.Car Manufacturers:
#
# The possibility to built into the cars of early warning systems to unnable the driver to adapt his driving style to the expereinced circumtstances on the road.
#
#
#
# 1.4.The Insurance Companies:
#
# They can use the outcome of these models to lobby the leglislator in order to issue new laws to impose dispositions in order to contain the number and severity of the road accidents.
#
#
# Lobbying as such they would be able to lower the overall risk profile of their insurance portfolio and as such reducing the exposrue of the 'Names' which finance the subscription of the portfolio.
#
#
#
# 1.5.The Consumers:
#
# 1.5.1.The can benefit various way of such prediction models:
#
# 1.5.1.1.The can early warnings to adapt the driving style this by messages on roadside boards, radio messages, text messages on mobile devices.
#
#
# 1.5.1.2.Early warning through electronic devices wethether or not built into their cars.
#
#
# 1.6.In conclusion:
#
# We all have consiberable advantages of such models, less accidents, less casyalties,lower emergency help budgets for the autorities, cheaper insucrance contracts seeing the overall lower risk profile, less time wasted in traffic jams due to rescue operations on road accidents.

# %% [markdown]
# 2.Preparing and modelling our DataFrame for the use with our various ML models.
#
#
# 2.1.Preparing Data
#
# A first look at our data set reveals we will have to balance the whole to avoid bias.
# We also notice that most variables are catogorical variables which we will have to transform in order to able to use in our ML models.
#
# De target values of column 'SEVERITYCODES' out of only vaiables which allows us to reduce the scoop of ML models to be evaluated.
#
# We will be using suppervised ML models in which we will be splitting the data frame in two sets one for training(80%) and one for testing (20%).
#
# First step in modelling our data.
#
# We identify the features with nill values and remove them.
#
# The new data set resulting out this operation is strongly reduced data set comapred wiith the original.
#
# The size of the new set is only 4% of the initial one (96% loss).
#
# At this stage we notice that we maybe will have to analyze the  data which we removed to see by how much it affects the quality of the data set we will be using for our various ML models.
#
#
#
# 2.1.Visualization of our DataFrame after modelling
#
# For the features 'Weather', 'Lightcond', 'Roadcond'  we plot the total of all labels.
#
#
#
# 2.2.1.The Weather Feature
#
# While looking we notice that for the Weather conditions , if we accept that the label 'overcast' linked  is to rainy period , the number of accidents during clear and overcasted weahter conditions are about of the same order size.
#
# The other labels are considerably much smaller in size.

# %% [markdown]
# ![weather.png](attachment:weather.png)

# %% [markdown]
# 2.2.2.The Roadcond Feature
#
# For the 'Roadcond' we observe that the number of accidents during wet conditions and dry conditions are from the same order size.
#
# The other lables are considerable smaller.

# %% [markdown]
# ![roadcond.png](attachment:roadcond.png)

# %% [markdown]
# 2.2.3.The Lightcond Feature
#
# For the 'Lightcond' we observe that the number accidents by light conditions and the dark-streetlight conditions about the same order size are.
#
# The other labels are considerabale smaller.

# %% [markdown]
# ![lightcond.png](attachment:lightcond.png)

# %% [markdown]
# 2.2.4. The number and the severity imputed to the weather conditions.
#
# For the labels raining, overcast and clear we see that  the number of injuries about 1/3 is of the whole, 2/3 are prop damages.
#
# Other labels apeers hardly to have any impact.

# %% [markdown]
# ![weather-severity.png](attachment:weather-severity.png)

# %% [markdown]
# 2.2.5. The number and the severity imputed to the road conditions.
#
# For the 'wet' label about 1/3 accidents are injuries the others 2/3 are property damages.
#
# With the 'dry' label circumstances are a bit different about 40%  of the accidents are with injuries ,  the remaining 60% are property damages.
#
# The other lables have apparently hardly any impact.

# %% [markdown]
# ![roadcond-severity.png](attachment:roadcond-severity.png)

# %% [markdown]
# 2.2.6.The number and the severity imputed to the light conditions.
#
# For the light conditions the labels day-light and dark-street light are predominant.
#
# For the day-light label about 40% are injuries and the 60% are property damages.
#
# The proportions for the Dark-street light label are a bit different about 1/3 are injuries the other 2/3 are property damages.

# %% [markdown]
# ![lightcond-severity.png](attachment:lightcond-severity.png)

# %% [markdown]
# 2.3 Identifciation of the unique labels of the categrical features we will be using.
#
#
#
# 2.3.1 for the features WEATHER, ROADCOND, LIGHTCOND,JUNCTIONTYPE,SPEEDING we determine the list of unique labels
#
# WEATHER= Clear', 'Raining', 'Overcast', 'Snowing', 'Fog/Smog/Smoke','Unknown', 'Blowing Sand/Dirt', 'Sleet/Hail/Freezing Rain','Other', 'Severe Crosswind'
#
# ROADCOND= Dry', 'Wet', 'Snow/Slush', 'Ice', 'Other', 'Unknown','Sand/Mud/Dirt', 'Standing Water', 'Oil'
#
# LIGHTCOND='Daylight', 'Dark - Street Lights On', 'Dusk', 'Dawn','Dark - Street Lights Off', 'Dark - No Street Lights', 'Unknown','Other'
#
# JUNCTIONTYPE= 'At Intersection (intersection related)','Mid-Block (not related to intersection)','Mid-Block (but intersection related)', 'Driveway Junction','At Intersection (but not related to intersection)','Ramp Junction', 'Unknown'
#
#
# SPEEDING = 'Y'
#
#
#
# 2.3.2.Final step in attributing a numerical value to our labels in the features.
#
#
#
# 2.3.2.1 Filling in the missing data per feature using the policy of the means and attributing the numeroical value to each label
#
# Numerification of the labels for the features'WEATHER',"ROADCOND','LIGHTCOND',
# 'JUNCTIONTYPE' and 'SPEEDING'.
#
# All the numerficated features are assigned to a new DataFrame  X.
#
# Numerification of the target value and stoed in a new Dataframe y.
#
#
#
#
# 2.3.2.2.Standardization of the DataFrame X.
#
# We standardize our dataset and allow the integers to become floats.
#
#
#
# 2.3.2.3.Setting up the training and the test set for our ML models.
#
# We split our data into two sets, the training set contains 80% and the test set contaoins the 20% of our dataframe.
#
# Train set: (6920, 9) (6920,)
# Test set: (1731, 9) (1731,)

# %% [markdown]
# 3.Our ML models K-Neighbors, Decision Tree Model, Logistic Regression and Support Vector Machine model.
#
#
#
# 3.1.Our first prediction model : K- Neighbors
#
# We will perform  50 simulation iterations  to find out which K value gives the most acurate result.
#
# Visualization shows us that our K-neighbors model performs best with a K= 44.

# %% [markdown]
# ![k-values.png](attachment:k-values.png)

# %% [markdown]
# 3.1.1.We will present our results by the means of a confusion matrix
#
# The matrix of our  presentation:
#
# [113 542]
# [103 973]

# %% [markdown]
# ![K-neigh.png](attachment:K-neigh.png)

# %% [markdown]
# ![F1_score_K-Neighbors.png](attachment:F1_score_K-Neighbors.png)

# %% [markdown]
# 3.1.2.Jaccard classification evaluation for K-Neighbors model.
#
# Jaccard_score: 0.6013

# %% [markdown]
# 3.1.3.Log_loss classification evaluation for K-Neighbors model.
#
# Log_loss_score: 0.6530

# %% [markdown]
# 3.2 Our second prediction model being Decision Tree model
#
#
# Our Decision Tree model has follwoing caracteristics :
#
# - DecisionTreeClassifier(criterion='entropy', max_depth=4)
#
#
#
# 3.2.1. We will present our results by the means of a confusion matrix
#
# [113 542]
# [103 973]

# %% [markdown]
# ![Decision_Tree_Matrix.png](attachment:Decision_Tree_Matrix.png)

# %% [markdown]
# ![F1-score-Decision-tree.png](attachment:F1-score-Decision-tree.png)

# %% [markdown]
# 3.2.2.Jaccard classification evaluation for Decision Tree model.
#
# Jaccard_score: 0.6013

# %% [markdown]
# 3.2.3.Log_loss classification evaluation for Decision Tree model.
#
# Logloss_score : 0.6530

# %% [markdown]
# 3.3 Our third prediction model being Logistic Regression.
#
#
# Our Logestic Regression model has follwoing caracteristics :
#
# - LogisticRegression(C=0.01, solver='liblinear')
#
#
# 3.3.1.We will present our results by the means of a confusion matrix.
#
#
# [43  612]
# [26 1050]

# %% [markdown]
# ![Matrix_logistic_regression.png](attachment:Matrix_logistic_regression.png)

# %% [markdown]
# ![F1_score_logistic_regression.png](attachment:F1_score_logistic_regression.png)

# %% [markdown]
# 3.3.2.Jaccard classification evaluation for Logistic Regression model:
#
# Jaccard_score: 0.6220

# %% [markdown]
# 3.3.3.Log_loss classification evaluation for Logistic Regression model:
#
# Log_loss_score: 0.76698

# %% [markdown]
# 3.4 Our fourth prediction model being Support Vector Machine model.
#
# 3.4.1.Our first Support Vector Machine model has as kernel = 'rbf' .
#
#
#
# 3.4.1.1.We will present our results by the means of a confusion matrix.
#
#
# [42  613]
# [33 1043]

# %% [markdown]
# ![Matrix_support-vector-machine-rbj.png](attachment:Matrix_support-vector-machine-rbj.png)

# %% [markdown]
# ![F1-score-support-vector-machine-rbj.png](attachment:F1-score-support-vector-machine-rbj.png)

# %% [markdown]
# 3.4.1.2.Jaccard classification evaluation for Support Vector Machine model with kernel='rbf':
#
# Jaccard_score: 0.6175

# %% [markdown]
# 3.4.1.3.Log_loss classification evaluation for Support Vector Machine model with kernel ='rbf':
#
# Log_loss_score: 0.6519

# %% [markdown]
# 3.4.2.Our second Support Vector Machine model has as kernel = 'linear' .
#
#
#
# 3.4.2.1.We will present our results by the means of a confusion matrix.

# %% [markdown]
# ![matrix_vector-support-machine-linear.png](attachment:matrix_vector-support-machine-linear.png)

# %% [markdown]
# ![F1-score-support-vextor-machine-linear.png](attachment:F1-score-support-vextor-machine-linear.png)

# %% [markdown]
# 3.4.2.2.Jaccard classification evaluation for Support Vector Machine model with kernel='linear':
#
# Jaccard_score: 0.6259

# %% [markdown]
# 3.4.2.3.Log_loss classification evaluation for Support Vector Machine model with kernel ='linear':
#
# Log_loss_score: 0.6519

# %% [markdown]
# 4.Comments on the obtained results:
#
#
# 4.1.Going through the results obtained with our various models , the conclsuion is anything but joyfull.
#
# If we compare the accuracy of the F1 score using the weighted average as comparator, the conclusion is rather saddening in this sense that our ML models we have being using or tossing a coin in order to predict the right outcome is of the same order being 50%.
#
#
# 4.2.Before looking to adapt our ML models , I am personally convinced that we are missing vital data in the DataFrame we are using.
#
# Starting with our target value being binary 'injury' or 'prop damage' , there were initally a more elaborateed set of labels used.
#
# But more vital information is missing for instance wethether we are dealing with an accident with  pedesterians , bicycles, motorbike, cars.
#
#
# Also the outcome of an accident such as fatal or not could facilitate the qualification of a accident.
#
#
# 4.3.A final comment, I am not in a postion to be able to determine the causes but our initial size of our DataFrame consist of 194673 rows and after preparing the dataset for our models the size is reduced to 8651 rows with other words 96%  of our observations are lost for usage due to missing data.
#
#
#
# 4.4.The loss of 96% percent of our observations has its toll on the performance of our models, as known the larger your sample population the more accuracy can be expected.
#
# So the question is are these 8651 observations we use for our ML models reprensative enough to make predictions.
#
#
#
# 4.5.In the actual state of our project , tossing up a coin would be the most economical way to seek an answer to our question about the prediction of the outcome of an accident.

# %% [markdown]
# 5.Final conclusion:
#
#
#
# 5.1.As first step we have to go back to our data in order to be able to add signifiant features which would improve the performance of our models, if this doesn't resolves the predactiblity of our models taking inroads to improve reporting to have more complete dataframes will be a  second step.
#
#
#
# 5.2.If these steps wouldn't help out then the next step would  be to evalaute if the information we collect really adequate is and if so then how effective our reporting is in function of our prediction models.
